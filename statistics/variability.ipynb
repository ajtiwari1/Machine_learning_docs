# %% [markdown]
# 1. Range
# 2. Mean Absolute Deviation
# 3. standard  Deviation
# 4. variance
# 5. percentile , quantile ,IQR,box plot

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("titanic.csv")

# %%
max_val=df["Age"].max()

# %%
min_val=df["Age"].min()

# %%
range =max_val-min_val

# %%
range
# Out:
# np.float64(79.58)

# %%
data1=np.array([90,46,43,87,55])
data2=np.array([68,60,63,71,59])

# %%
mean1=data1.mean()

# %%
mean2=data2.mean()

# %%
mad1= np.sum(np.abs(data1-mean1))/len(data1)

# %%
mad2= np.sum(np.abs(data2-mean2))/len(data2)

# %%
mad1,mad2
# Out:
# (np.float64(19.44), np.float64(4.24))

# %%
plt.scatter(data1,no_table)
plt.scatter(data2,no_table)
plt.plot([ mean1 for i in range(90)],[i for i in range(90)],color="blue")
plt.show()

# %%
no_table=np.array([1,2,3,4,5])

# %%
mean1
# Out:
# np.float64(64.2)

# %%
data1.var()
# Out:
# np.float64(410.16)

# %%
##percentile
np.percentile(df["Fare"],75)
# Out:
# np.float64(31.0)

# %%
df["Fare"].min()
# Out:
# np.float64(0.0)

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.histplot(x="Age",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
